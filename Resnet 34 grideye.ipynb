# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread('E:\data\PersonB\Sit\Sit1\Data2\\21.png')
plt.imshow(img)

# %%
from tensorflow.keras.preprocessing import image
img_path = 'E:\data\PersonB\Sit\Sit1\Data2\\21.png'
img = image.load_img(img_path, target_size=(224, 224))
img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img.shape
# Out:
# (1, 224, 224, 3)

# %%
from __future__ import absolute_import, division, print_function
import tensorflow as tf
from models.resnet import resnet_34
#import config
#from prepare_data import generate_datasets
import math


def get_model():
    model = resnet_34()
    model.build(input_shape=(1, 244, 244, 3))
    model.summary()
    return model


if __name__ == '__main__':
    
    # create model
    model = get_model()
    
    predictions = model(img, training=True)
    
    print('end')
    print(predictions.shape)
# Out:
# Model: "res_net_type_i_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_90 (Conv2D)           multiple                  9472
# _________________________________________________________________
# batch_normalization_90 (Batc multiple                  256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 multiple                  0
# _________________________________________________________________
# sequential_15 (Sequential)   multiple                  74368
# _________________________________________________________________
# sequential_16 (Sequential)   multiple                  2008448
# =================================================================
# Total params: 2,092,544
# Trainable params: 2,088,320
# Non-trainable params: 4,224
# _________________________________________________________________
# end
# (1, 28, 28, 128)
